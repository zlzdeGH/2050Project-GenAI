# %%
import pandas as pd

# %%
import re
df = pd.read_csv('Policy_2024.csv')

is_complex = df['Course Code'].str.contains('/', na=False)
complex_codes_df = df[is_complex]

# %%
def analyze_code_parts(row):

    code_str = row['Course Code']
    if not isinstance(code_str, str) or not code_str:
        return pd.Series([0, 0, 0], index=['dept_len', 'num_len', 'max_num_val'])
        
    # Find all alphabetic parts (department codes) and numeric parts
    dept_parts = re.findall(r'[A-Z]+', code_str, re.IGNORECASE)
    num_parts = re.findall(r'\d+', code_str)
    
    # Calculate lengths and max value
    max_dept_len = max(len(p) for p in dept_parts) if dept_parts else 0
    max_num_len = max(len(p) for p in num_parts) if num_parts else 0
    max_num_val = max(int(p) for p in num_parts) if num_parts else 0
    
    return pd.Series([max_dept_len, max_num_len, max_num_val], index=['dept_len', 'num_len', 'max_num_val'])

df[['dept_len', 'num_len', 'max_num_val']] = df.apply(analyze_code_parts, axis=1)
df['total_len'] = df['Course Code'].str.len()

# %%
short_dept = df[(df['dept_len']>0) & (df['dept_len']<3)]['Course Code']
short_dept
# Out:
# Series([], Name: Course Code, dtype: object)

# %%
long_dept = df[df['dept_len']>4]['Course Code']
long_dept
# Out:
# Series([], Name: Course Code, dtype: object)

# %%
short_num = df[(df['num_len']>0) & (df['num_len']<3)]['Course Code']
short_num
# Out:
# Series([], Name: Course Code, dtype: object)

# %%
long_num = df[(df['num_len']>4)]['Course Code']
long_num
# Out:
# 45    HMN 2402A/MCM 25100/POBS 2400
# Name: Course Code, dtype: object

# %%
large_num = df[df['max_num_val']>3000]['Course Code']
large_num
# Out:
# 45    HMN 2402A/MCM 25100/POBS 2400
# Name: Course Code, dtype: object

# %%
short_code = df[(df['total_len']>0) & (df['total_len']<8)]['Course Code']
short_code
# Out:
# 948    PHP 310
# Name: Course Code, dtype: object

# %%
long_code = df[df['total_len']>10]['Course Code']
long_code
# Out:
# 3                            ENVS/EEPS 1615
# 45            HMN 2402A/MCM 25100/POBS 2400
# 47                           PHYS 1600/2600
# 133                          PHYS 1100/2100
# 134                   COLT 2650Y/ENGL 2561Z
# 154                          BIOL 1260/2260
# 217                          CSCI  410/1411
# 254                          APMA 1740/2610
# 287                          BIOL 2040/1040
# 368                          BIOL 1260/2260
# 374                     ENGN/PHYS 1590/2590
# 397                          PHYS 1610/2630
# 408                          PHYS 1600/2600
# 409                          CSCI 1550/2540
# 411                        ENGN 0930L/1930L
# 423                          BIOL 1515/2015
# 454                     ENGN/PHYS 1590/2590
# 482                          ANTH 1976/2401
# 488                          PHYS 0720/1720
# 492                          HIAA 1721/2721
# 515                          ENGN 1735/2735
# 526                    JUDS 0060/RELS 0060C
# 540                          COST/RELS 0565
# 550     SAST 0740 / RELS 0580A / HIST 0980R
# 562                          BIOL 1050/2050
# 571                          BIOL 1560/2560
# 575                          BIOL 1050/2050
# 578                        ENGN 0930L/1930L
# 599                          PHYS 0720/1720
# 623                     POLS 2285/MCM 2110G
# 632                          PHYS 1640/2640
# 633                    SAST 0745/HIST 0980S
# 640                          PHYS 1640/2640
# 668                          CSCI  410/1411
# 721                          HIAA 1721/2721
# 730                          BIOL 1560/2560
# 732                     COST 0725/RELS 0725
# 775                          MUSC 0620/0621
# 822                     ENGN/PHYS 1590/2590
# 876                          ENVS/EEPS 1615
# 903                    RELS 0842/AMST 0170F
# 910                     COST 0725/RELS 0725
# 1006                         BIOL 2040/1040
# 1046                         ENGN 1735/2735
# 1109                   JUDS 0060/RELS 0060C
# 1138                         PHYS 1100/2100
# 1143                   ANTH 1504/LACA 1504P
# 1159                       ENGN 0931L/1931L
# 1184                         ANTH 1976/2401
# 1202                         PHYS 1610/2630
# 1231                     PHP 1880/COST 1080
# 1250                         BIOL 1515/2015
# 1294                         COST/RELS 0565
# 1344                    ENGN/PHYS 1590/2590
# 1350                         BIOL 1575/2075
# 1367                         APMA 1740/2610
# 1388                         CSCI 1550/2540
# 1445                  BIOL 1270 / BIOL 2270
# 1461                       ENGN 0931L/1931L
# Name: Course Code, dtype: object

# %%
sum(long_code== complex_codes_df['Course Code']) == len(long_code)
# Out:
# True

# %%
unk = df[(df['Course Code'].notna()) &(df['Department'] == 'Unknown')]
unk
# Out:
#                                                File  \
# 18     0KNlHq1TXUCS4yGz2hSMsTZD2WQUOBF6Eo2SZqWm.pdf
# 45     1oSdGXXX4qTQbXBwU13zCq9bfgBjg4b2d6CHl4dT.pdf
# 85     36DDUbawS1vrklHltmNWlCj4eYRLBTou5G1aHWds.pdf
# 92     3GZAZtL71jArylKwiVq1sq5OealwWRLmWdjzQI2N.pdf
# 118    4Xqw4yle5ItntFel5L3GRXuV2vJORUedkjrRUDkw.pdf
# 122    56UmS471oPGZK54JywMkjFzKzvfNxAnLFmJtoYvQ.pdf
# 179    7nfVKqylRoyRkvKXEA4VW0tEPsWxkqr1Xnh0IKYf.pdf
# 245   ALvvW29UUkapGdqn64rJg13TBHyBckmpREf0qyXx.docx
# 277    BWV7KtnYqi78PgAKV1frgFnq7vnj3xxeJpKqr5oh.pdf
# 458    JIrBKvxQM99w6tqbciEvGiOdN164aYS0G6jMzvxf.pdf
# 506   Ls8ytq1MZ6GVx7HbKTWapyBiHw9iIgO4pvN3XrCo.docx
# 549    NJDIWZxDDOwESz6jtUnrVYQ4vOzKZIl3V1ACzCFz.pdf
# 550    NLfC82PWET1syH11Rnq3jWjB1RMAwPDhuK3ps3bS.pdf
# 551   Nm4mqZMwyEJidbXKD4ytaP8uRqogeoTGKWti44lf.docx
# 579    ORf4PXoRtQosFoD1xLj7PYr0h7f7gxiw5RpZScBI.pdf
# 617   QaCAi3tYRkoH8yLBYK6HDh00XSvJd73GOC0LEh4G.docx
# 633    QsTG6RznDmptRhEzW40wWtAKnKbkMlsI0WnyL2zF.pdf
# 646    RMHEE6WvVQgQIgDHFu92zYO44irDiM3OVudz046F.doc
# 655    Ru2mAJQ9LuKD9SKu0ZtRpFJWxx0ITGg3In5OsKqG.pdf
# 699    TGJ2WduOH6eZJKt6HPBhYpNiQnPRp1btwk6R73T2.pdf
# 852   Xwu7z6iwxL6IXqwuN3UYJ62VD07CG2bYNl8nJjM2.docx
# 1132   l4Y2jKCh1l1OEdlbzXjhJtT01XehJqKux7T1RTMN.pdf
# 1154   m9oh0Df7tf7Wd2I4xsD4VxO3DWSazGZk9BOiT3Hv.pdf
# 1170   mTDvNAIutJEPqnojBxdzYFku3aqpLU4iMIzyFD65.pdf
# 1434  xqEfC587DzHbIx84AB3PvwDP30feMfhgX19mIuAa.docx
#
#                               Course Code Department Knowledge Area  \
# 18                              GREK 1810    Unknown        Unknown
# 45          HMN 2402A/MCM 25100/POBS 2400    Unknown        Unknown
# 85                              GREK 1150    Unknown        Unknown
# 92                              GREK 1060    Unknown        Unknown
# 118                             LACA 1900    Unknown        Unknown
# 122                             UNIV 1110    Unknown        Unknown
# 179                            LACA 1504Q    Unknown        Unknown
# 245                            LACA 1504R    Unknown        Unknown
# 277                             UNIV 1221    Unknown        Unknown
# 458                             UNIV 1211    Unknown        Unknown
# 506                             GEOL 1320    Unknown        Unknown
# 549                             GREK 0200    Unknown        Unknown
# 550   SAST 0740 / RELS 0580A / HIST 0980R    Unknown        Unknown
# 551                             GISP 0003    Unknown        Unknown
# 579                             UNIV 0901    Unknown        Unknown
# 617                             PLME 0700    Unknown        Unknown
# 633                  SAST 0745/HIST 0980S    Unknown        Unknown
# 646                             UNIV 0400    Unknown        Unknown
# 655                             UNIV 1221    Unknown        Unknown
# 699                             UNIV 1221    Unknown        Unknown
# 852                             PLME 0300    Unknown        Unknown
# 1132                            UNIV 1221    Unknown        Unknown
# 1154                           GREK 1100G    Unknown        Unknown
# 1170                            UNIV 1210    Unknown        Unknown
# 1434                            GEOL 0250    Unknown        Unknown
#
#                                               AI Policy  Multiple Clusters  \
# 18                                                  NaN                  0
# 45                                                  NaN                  0
# 85                                                  NaN                  0
# 92                                                  NaN                  0
# 118   Submitting work completed using artificial int...                  1
# 122   As such, it is important that the work you pre...                  0
# 179                                                 NaN                  0
# 245                                                 NaN                  0
# 277                                                 NaN                  0
# 458                                                 NaN                  0
# 506                                                 NaN                  0
# 549                                                 NaN                  0
# 550                                                 NaN                  0
# 551                                                 NaN                  1
# 579   AI POLICY AI tools can generate text, images, ...                  0
# 617                                                 NaN                  0
# 633   AI Writing Tools: You are free to explore the ...                  0
# 646   It has been noticed that some students may hav...                  0
# 655                                                 NaN                  0
# 699                                                 NaN                  0
# 852   AI content is not allowed in the final assignm...                  1
# 1132                                                NaN                  0
# 1154  Please do not use any AI program (including Gr...                  0
# 1170  The goal of much of the writing in this course...                  0
# 1434                                                NaN                  0
#
#       LLM Failure  dept_len  num_len  max_num_val  total_len
# 18              0         4        4         1810          9
# 45              0         4        5        25100         29
# 85              0         4        4         1150          9
# 92              0         4        4         1060          9
# 118             0         4        4         1900          9
# 122             0         4        4         1110          9
# 179             0         4        4         1504         10
# 245             0         4        4         1504         10
# 277             0         4        4         1221          9
# 458             0         4        4         1211          9
# 506             0         4        4         1320          9
# 549             0         4        4          200          9
# 550             0         4        4          980         35
# 551             0         4        4            3          9
# 579             0         4        4          901          9
# 617             0         4        4          700          9
# 633             0         4        4          980         20
# 646             0         4        4          400          9
# 655             0         4        4         1221          9
# 699             0         4        4         1221          9
# 852             0         4        4          300          9
# 1132            0         4        4         1221          9
# 1154            0         4        4         1100         10
# 1170            0         4        4         1210          9
# 1434            0         4        4          250          9

# %%
def find_union_and_sort(list_of_number_sets):

    if not list_of_number_sets:
        return []

    union_set = set().union(*(set(s) for s in list_of_number_sets))

    return sorted(list(union_set))


sets = [short_dept.index, short_code.index, unk.index]
idx = find_union_and_sort(sets)
print(f" Index that need be checked: {idx}")
# Out:
#  Index that need be checked: [18, 45, 85, 92, 118, 122, 179, 245, 277, 458, 506, 549, 550, 551, 579, 617, 633, 646, 655, 699, 852, 948, 1132, 1154, 1170, 1434]

# %% [markdown]
# #### 3.summarize the code we might need check finally

# %%
pd.set_option('display.max_rows', 150)
df.iloc[idx]
# final_unknown = df.iloc[idx]
# final_unknown.to_csv('final_unknown.csv')
# Out:
#                                                File  \
# 18     0KNlHq1TXUCS4yGz2hSMsTZD2WQUOBF6Eo2SZqWm.pdf
# 45     1oSdGXXX4qTQbXBwU13zCq9bfgBjg4b2d6CHl4dT.pdf
# 85     36DDUbawS1vrklHltmNWlCj4eYRLBTou5G1aHWds.pdf
# 92     3GZAZtL71jArylKwiVq1sq5OealwWRLmWdjzQI2N.pdf
# 118    4Xqw4yle5ItntFel5L3GRXuV2vJORUedkjrRUDkw.pdf
# 122    56UmS471oPGZK54JywMkjFzKzvfNxAnLFmJtoYvQ.pdf
# 179    7nfVKqylRoyRkvKXEA4VW0tEPsWxkqr1Xnh0IKYf.pdf
# 245   ALvvW29UUkapGdqn64rJg13TBHyBckmpREf0qyXx.docx
# 277    BWV7KtnYqi78PgAKV1frgFnq7vnj3xxeJpKqr5oh.pdf
# 458    JIrBKvxQM99w6tqbciEvGiOdN164aYS0G6jMzvxf.pdf
# 506   Ls8ytq1MZ6GVx7HbKTWapyBiHw9iIgO4pvN3XrCo.docx
# 549    NJDIWZxDDOwESz6jtUnrVYQ4vOzKZIl3V1ACzCFz.pdf
# 550    NLfC82PWET1syH11Rnq3jWjB1RMAwPDhuK3ps3bS.pdf
# 551   Nm4mqZMwyEJidbXKD4ytaP8uRqogeoTGKWti44lf.docx
# 579    ORf4PXoRtQosFoD1xLj7PYr0h7f7gxiw5RpZScBI.pdf
# 617   QaCAi3tYRkoH8yLBYK6HDh00XSvJd73GOC0LEh4G.docx
# 633    QsTG6RznDmptRhEzW40wWtAKnKbkMlsI0WnyL2zF.pdf
# 646    RMHEE6WvVQgQIgDHFu92zYO44irDiM3OVudz046F.doc
# 655    Ru2mAJQ9LuKD9SKu0ZtRpFJWxx0ITGg3In5OsKqG.pdf
# 699    TGJ2WduOH6eZJKt6HPBhYpNiQnPRp1btwk6R73T2.pdf
# 852   Xwu7z6iwxL6IXqwuN3UYJ62VD07CG2bYNl8nJjM2.docx
# 948   drKDJFOSiUP28BQfEMexVN7xx1RVVkSw9hNicRcG.docx
# 1132   l4Y2jKCh1l1OEdlbzXjhJtT01XehJqKux7T1RTMN.pdf
# 1154   m9oh0Df7tf7Wd2I4xsD4VxO3DWSazGZk9BOiT3Hv.pdf
# 1170   mTDvNAIutJEPqnojBxdzYFku3aqpLU4iMIzyFD65.pdf
# 1434  xqEfC587DzHbIx84AB3PvwDP30feMfhgX19mIuAa.docx
#
#                               Course Code     Department Knowledge Area  \
# 18                              GREK 1810        Unknown        Unknown
# 45          HMN 2402A/MCM 25100/POBS 2400        Unknown        Unknown
# 85                              GREK 1150        Unknown        Unknown
# 92                              GREK 1060        Unknown        Unknown
# 118                             LACA 1900        Unknown        Unknown
# 122                             UNIV 1110        Unknown        Unknown
# 179                            LACA 1504Q        Unknown        Unknown
# 245                            LACA 1504R        Unknown        Unknown
# 277                             UNIV 1221        Unknown        Unknown
# 458                             UNIV 1211        Unknown        Unknown
# 506                             GEOL 1320        Unknown        Unknown
# 549                             GREK 0200        Unknown        Unknown
# 550   SAST 0740 / RELS 0580A / HIST 0980R        Unknown        Unknown
# 551                             GISP 0003        Unknown        Unknown
# 579                             UNIV 0901        Unknown        Unknown
# 617                             PLME 0700        Unknown        Unknown
# 633                  SAST 0745/HIST 0980S        Unknown        Unknown
# 646                             UNIV 0400        Unknown        Unknown
# 655                             UNIV 1221        Unknown        Unknown
# 699                             UNIV 1221        Unknown        Unknown
# 852                             PLME 0300        Unknown        Unknown
# 948                               PHP 310  Public Health  Life Sciences
# 1132                            UNIV 1221        Unknown        Unknown
# 1154                           GREK 1100G        Unknown        Unknown
# 1170                            UNIV 1210        Unknown        Unknown
# 1434                            GEOL 0250        Unknown        Unknown
#
#                                               AI Policy  Multiple Clusters  \
# 18                                                  NaN                  0
# 45                                                  NaN                  0
# 85                                                  NaN                  0
# 92                                                  NaN                  0
# 118   Submitting work completed using artificial int...                  1
# 122   As such, it is important that the work you pre...                  0
# 179                                                 NaN                  0
# 245                                                 NaN                  0
# 277                                                 NaN                  0
# 458                                                 NaN                  0
# 506                                                 NaN                  0
# 549                                                 NaN                  0
# 550                                                 NaN                  0
# 551                                                 NaN                  1
# 579   AI POLICY AI tools can generate text, images, ...                  0
# 617                                                 NaN                  0
# 633   AI Writing Tools: You are free to explore the ...                  0
# 646   It has been noticed that some students may hav...                  0
# 655                                                 NaN                  0
# 699                                                 NaN                  0
# 852   AI content is not allowed in the final assignm...                  1
# 948                                                 NaN                  1
# 1132                                                NaN                  0
# 1154  Please do not use any AI program (including Gr...                  0
# 1170  The goal of much of the writing in this course...                  0
# 1434                                                NaN                  0
#
#       LLM Failure  dept_len  num_len  max_num_val  total_len
# 18              0         4        4         1810          9
# 45              0         4        5        25100         29
# 85              0         4        4         1150          9
# 92              0         4        4         1060          9
# 118             0         4        4         1900          9
# 122             0         4        4         1110          9
# 179             0         4        4         1504         10
# 245             0         4        4         1504         10
# 277             0         4        4         1221          9
# 458             0         4        4         1211          9
# 506             0         4        4         1320          9
# 549             0         4        4          200          9
# 550             0         4        4          980         35
# 551             0         4        4            3          9
# 579             0         4        4          901          9
# 617             0         4        4          700          9
# 633             0         4        4          980         20
# 646             0         4        4          400          9
# 655             0         4        4         1221          9
# 699             0         4        4         1221          9
# 852             0         4        4          300          9
# 948             0         3        3          310          7
# 1132            0         4        4         1221          9
# 1154            0         4        4         1100         10
# 1170            0         4        4         1210          9
# 1434            0         4        4          250          9

# %%
complex_codes_df

# complex_codes_df.to_csv('complex_code.csv')

# %%
sum(df['AI Policy'].notna())/len(df)
# Out:
# 0.3406813627254509

# %%
df['Department'].value_counts()
# Out:
# Department
# Engineering                                          99
# Public Health                                        92
# English                                              82
# Economics                                            73
# Political Science                                    64
# History                                              63
# Biology                                              57
# Watson Institute                                     52
# Physics                                              47
# Applied Mathematics                                  47
# Theatre Arts and Performance Studies                 42
# East Asian Studies                                   41
# Center for Language Studies                          38
# Mathematics                                          38
# Anthropology                                         36
# Classics                                             36
# Music                                                31
# Cognitive, Linguistic, and Psychological Sciences    31
# Religious Studies                                    30
# Sociology                                            28
# Education                                            28
# Modern Culture and Media                             26
# Unknown                                              25
# Environmental Studies                                25
# Visual Art                                           24
# Philosophy                                           23
# Comparative Literature                               23
# American Studies                                     23
# Hispanic Studies                                     22
# Earth, Environmental and Planetary Sciences          22
# French Studies                                       20
# Computer Science                                     20
# Literary Arts                                        17
# Slavic Studies                                       15
# German Studies                                       15
# History of Art and Architecture                      14
# Chemistry                                            14
# Italian Studies                                      14
# Pembroke Center Teach and Rearch                     13
# Linguistics                                          13
# Judaic Studies                                       11
# Cogut Institute for the Humanities                    9
# Africana Studies                                      9
# Archaeology and the Ancient World                     8
# Urban Studies                                         7
# Neuroscience                                          7
# Data Science Initiative                               5
# Egyptology and Assyriology                            5
# Portuguese and Brazilian Studies                      5
# Middle East Studies                                   3
# Brown Arts Institute                                  3
# Bio-Medical (PLME & MED)                              1
# Medieval Studies                                      1
# Name: count, dtype: int64

# %%
df['Knowledge Area'].value_counts()
# Out:
# Knowledge Area
# Humanities           568
# Social Sciences      427
# Physical Sciences    317
# Life Sciences        157
# Unknown               25
# Arts                   3
# Name: count, dtype: int64

# %%
df['word_count'] = df['AI Policy'].fillna('').str.split().str.len()
df[(df['word_count'] > 0) & (df['word_count'] < 50)]
# Out:
#                                                File Course Code  \
# 1      02132Fz4IaY2bIfLT6mFVqih10XNgBKNsfCDqz9H.pdf   MATH 0750
# 8      0DfIT6QWVbaGMhjrpgtBYWMynKuxEvcuymDWmfWf.pdf    PHP 2601
# 12     0g94gZaFW5zOCKRB1Yyow0IkmXOHNfu6b6PvnnqT.pdf   FREN 1410
# 23     0qeJIBcKNAKTasYeyYPTxYKjz0SWmuBm8IQcSfoS.pdf   CLPS 1255
# 30     0ZIn6gxgaNz4oSLh3hnXj6AOs6Wu5ErVC1VLhYK8.pdf   NEUR 1530
# ...                                             ...         ...
# 1442  xyRhHQhZAIiwEbkoO8f8B5L14DoT5ZtyEdSDzd4V.docx  HIST 1961F
# 1455  yIiwpJwhLamf1PHgtJg74u2uxAPZ0iKJDp1XIkfS.docx   PHIL 1593
# 1468   yy16Jl8X8OOchCIfmErBdPHZplHsXkauGKjL7Z4E.pdf    PHP 0320
# 1486   zgut86QgNelZN8m5Ua3vN6KgPjswleYfSLFfv1fS.doc    KREA 500
# 1494   zWmmLIfQC76ejGfCAm76aFpvI4yI92dAgSl3iIqO.pdf   MUSC 2290
#
#                                              Department     Knowledge Area  \
# 1                                           Mathematics  Physical Sciences
# 8                                         Public Health      Life Sciences
# 12                                       French Studies         Humanities
# 23    Cognitive, Linguistic, and Psychological Sciences    Social Sciences
# 30                                         Neuroscience      Life Sciences
# ...                                                 ...                ...
# 1442                                            History    Social Sciences
# 1455                                         Philosophy         Humanities
# 1468                                      Public Health      Life Sciences
# 1486                                 East Asian Studies         Humanities
# 1494                                              Music         Humanities
#
#                                               AI Policy  Multiple Clusters  \
# 1     Use of AI programs such as ChatGPT is not allo...                  0
# 8     It is expected that students taking this cours...                  0
# 12    Use of A-I (Chat-GPT or similar) is not author...                  0
# 23    Generally speaking, you are not authorized to ...                  1
# 30    AI This course is intended to build research, ...                  0
# ...                                                 ...                ...
# 1442  Please note that use of ChatGPT or other AI pr...                  1
# 1455  My Addendum: Use of AI/Chatbots is not allowed...                  0
# 1468  The use of any AI in this course is considered...                  0
# 1486  Youre strongly encouraged to exercise honesty ...                  0
# 1494  It is fine to use Chat-GPT or other AI tools i...                  0
#
#       LLM Failure  dept_len  num_len  max_num_val  total_len  word_count
# 1               0         4        4          750          9          17
# 8               0         3        4         2601          8          27
# 12              0         4        4         1410          9          12
# 23              0         4        4         1255          9          27
# 30              0         4        4         1530          9          25
# ...           ...       ...      ...          ...        ...         ...
# 1442            0         4        4         1961         10          20
# 1455            0         4        4         1593          9          15
# 1468            0         3        4          320          8          46
# 1486            0         4        3          500          8          19
# 1494            0         4        4         2290          9          31
#
# [201 rows x 12 columns]
