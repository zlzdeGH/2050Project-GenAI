# %%
import PyPDF2

def read_pdf_text(pdf_path, page_range=None):
    """
    Read text content from a PDF file

    Args:
        pdf_path: Path to the PDF file
        page_range: Optional tuple specifying the page range to read, 
                    e.g., (1, 5) reads pages 1 through 5 (0-based indexing)
    """
    try:
        # Open the PDF file
        with open(pdf_path, 'rb') as file:
            pdf_reader = PyPDF2.PdfReader(file)
            
            # Get the total number of pages
            total_pages = len(pdf_reader.pages)
            print(f"Total pages in PDF: {total_pages}")
            
            text_content = ""
            
            # Determine which pages to read
            if page_range:
                start, end = page_range
                # Ensure the page range is valid
                start = max(0, start)
                end = min(total_pages, end)
                page_range = range(start, end)
                print(f"Reading content from page {start+1} to {end}:")
            else:
                page_range = range(total_pages)
                print("Reading all pages:")
            
            # Extract text from each page
            for page_num in page_range:
                page = pdf_reader.pages[page_num]
                page_text = page.extract_text()
                if page_text:
                    text_content += f"Page {page_num+1}:\n{page_text}\n\n"
                    print(f"Successfully read page {page_num+1}")
                else:
                    print(f"No text content found on page {page_num+1}")
            
            return text_content
    
    except FileNotFoundError:
        print(f"Error: File {pdf_path} does not exist")
    except Exception as e:
        print(f"An error occurred while reading the PDF: {e}")
    return ""

# Example usage
if __name__ == "__main__":
    pdf_path = "example.pdf"  # Replace with your actual PDF path
    
    # Method 1: Read all pages
    full_text = read_pdf_text(pdf_path)
    print("\nFull document text:\n", full_text)
    
    # Method 2: Read a specific range of pages (e.g., pages 1 to 3, zero-based)
    # Specifying a page range overrides reading the entire document
    partial_text = read_pdf_text(pdf_path, page_range=(0, 3))
    print("\nPartial document text (pages 1–3):\n", partial_text)

# %%
import docx
from docx.shared import Inches

def read_docx_text(docx_path):
    """
    Read text content from a Word document and return a list of paragraphs

    Args:
        docx_path: Path to the Word document (.docx)
    """
    try:
        # Open the Word document
        doc = docx.Document(docx_path)
        
        # Extract document metadata
        info = {
            "Title": doc.core_properties.title if doc.core_properties.title else "No title",
            "Author": doc.core_properties.author if doc.core_properties.author else "Unknown author",
            "Created": doc.core_properties.created.strftime("%Y-%m-%d %H:%M:%S")
                       if doc.core_properties.created else "No creation time",
            "ParagraphCount": len(doc.paragraphs)
        }
        print(f"Document info:\n{info}\n")
        
        # Extract text from each paragraph
        all_text = ""
        paragraphs = []
        for i, para in enumerate(doc.paragraphs, 1):
            para_text = para.text.strip()
            if para_text:
                paragraphs.append(para_text)
                all_text += f"Paragraph {i}: {para_text}\n"
        
        print(f"Successfully read {len(paragraphs)} non-empty paragraphs\n")
        return all_text, paragraphs, info
    
    except FileNotFoundError:
        print(f"Error: File {docx_path} does not exist")
    except Exception as e:
        print(f"An error occurred while reading the Word document: {e}")
    return "", [], {}

# Example usage
if __name__ == "__main__":
    docx_path = "example.docx"  # Replace with your actual Word file path
    
    full_text, para_list, doc_info = read_docx_text(docx_path)
    
    # Print the first 3 paragraphs (example)
    print("First 3 paragraphs of the document:")
    for para in para_list[:3]:
        print("-", para)

# %%
# !pip install PyPDF2
import PyPDF2

def read_pdf_text(pdf_path, page_range=None):
    """
    Read text content from a PDF file

    Args:
        pdf_path: Path to the PDF file
        page_range: Optional tuple specifying the page range to read, 
                    e.g., (1, 5) reads pages 1 through 5 (0-based indexing)
    """
    try:
        # Open the PDF file
        with open(pdf_path, 'rb') as file:
            pdf_reader = PyPDF2.PdfReader(file)
            
            # Get the total number of pages
            total_pages = len(pdf_reader.pages)
            print(f"Total pages in PDF: {total_pages}")
            
            text_content = ""
            
            # Determine which pages to read
            if page_range:
                start, end = page_range
                # Ensure the page range is valid
                start = max(0, start)
                end = min(total_pages, end)
                page_range = range(start, end)
                print(f"Reading content from page {start+1} to {end}:")
            else:
                page_range = range(total_pages)
                print("Reading all pages:")
            
            # Extract text from each page
            for page_num in page_range:
                page = pdf_reader.pages[page_num]
                page_text = page.extract_text()
                if page_text:
                    text_content += f"Page {page_num+1}:\n{page_text}\n\n"
                    print(f"Successfully read page {page_num+1}")
                else:
                    print(f"No text content found on page {page_num+1}")
            
            return text_content
    
    except FileNotFoundError:
        print(f"Error: File {pdf_path} does not exist")
    except Exception as e:
        print(f"An error occurred while reading the PDF: {e}")
    return ""

# Example usage
if __name__ == "__main__":
    pdf_path = "C:/Users/zlzdego/Downloads/AY 2023-2024/AY 2023-2024/JbtHutpwaVcqwaYdfqWpgP3m0s0Ai8tYaTcYUUHD.pdf"  # Replace with your actual PDF path
    
    # Method 1: Read all pages
    full_text = read_pdf_text(pdf_path)
    print("\nFull document text:\n", full_text)
    
    # Method 2: Read a specific range of pages (e.g., pages 1 to 3, zero-based)
    # Specifying a page range overrides reading the entire document
    partial_text = read_pdf_text(pdf_path, page_range=(0, 3))
    print("\nPartial document text (pages 1–3):\n", partial_text)
# Out:
# Requirement already satisfied: PyPDF2 in d:\anaconda\lib\site-packages (3.0.1)
# Total pages in PDF: 4
# Reading all pages:
# Successfully read page 1
# Successfully read page 2
# Successfully read page 3
# Successfully read page 4
#
# Full document text:
#  Page 1:
# Brown University HMAN 2400U, Spring 2024  Into the Wild: Thinking Democracy Ecologically  Monday 3:00-5:30     Pembroke 003 Mark Cladis (off hrs Thurs 3:45-5:30)  Sharon Krause (off hrs Wed 12:30-2:30)  How are we to respond to ecological crises that interweave politics, economy, religion, and culture, and that affect and position people differently based on their race, class, gender, sexuality, and other aspects of their identities? What resources do we have—or can we create—for reimagining “the human” and the more-than-human in ways that might be emancipatory for both? What kinds of cultural efforts, artistic work, social practices, and political institutions might figure in this reimagining? This collaborative humanities seminar explores a diverse range of contemporary and historical works ranging from poetry, fiction, and film to theology, social and political theory, nature writing, and environmental studies, including work by Wordsworth, Shelley, Bennett, Vogel, Du Bois, Gomez-Baris, Jarman, and Nixon, among others. The course emphasizes collaborative thinking and writing, both inside and outside the classroom.   Course Requirements (1) Regular attendance.  If you cannot attend a seminar, let us know in advance.  Read the assignments carefully and be prepared to say something about them during our conversations together.  Throughout the semester, we will endeavor to make connections between past and present sessions.    (2) Collaboratively hosting a class session: Groups of 2-3 students will host approximately the first half of one class session (written notes that reflect the dynamic, collaborative preparation for the session will be circulated in advance). Members of the hosting team are not expected to become experts for the sessions lead; they are expected to be informed readers and thoughtful hosts (educators) for our conversations.   (3) Final paper: A final paper of 20-25 pages due on May 13.    (4) Collaboratively edited volume: The final paper will be part of a larger, edited volume of 3 to 5 papers, conceived collaboratively by small groups of students and with a collaboratively written Introduction. Later in the seminar we will discuss the logistics for this edited volume. For now you should know that, based on shared interests, you will form groups of 3 to 5 and you will collaboratively develop a topic/focus for an edited book or journal that will include your final papers and you will co-author an Introduction to the volume.    (5) Retreat: Participation in the course retreat at the end of the term, including a presentation of your  ideas for the final paper and collaboratively edited volume.   Institutional Grade Evaluation Your letter grade will normally be calculated as follows:  Class participation, including hosting sessions: 25%  Collaboratively edited volume (its topic and introduction): 20%  Presentation at the retreat: 10%  Final Paper: 45%
#
# Page 2:
# Books for purchase: Vogel, Thinking Like a Mall Jane Bennett, Vibrant Matter W.E. B. Du Bois, The Souls of Black Folk  (University of Oxford edition) Rob Nixon, Slow Violence Macarena Gomez-Barris, The Extractive Zone Mary Shelley, Frankenstein (1818 version) ed. Marilyn Butler (Oxford World Classics) Derek Jarman, Modern Nature Additional readings indicated with an asterisk (*) on the syllabus will be made available via CANVAS.  Course Outline  Introduction  January 29: Thinking democracy ecologically (and collaboratively)   On Gardens: Art, Nature, Politics  February 5: •  Rousseau, Julie, trans. Judith McDowell  pp. 64-67;  301-315*    •  Derek Jarman’s film “The Garden” (https://archive.org/details/TheGarden_165) •  Melissa Zeiger, “‘Modern Nature’: Derek Jarman’s Garden”* •  Derek Jarman, Modern Nature, January-March 1989, May-September 1990, 3-47 and 284-314     Humanity and the “Natural World” in the Context of Modernity, Industrialization, and Capitalism   February 12:  • Wordsworth: “Expostulation and Reply,” “The Tables Turned,” “The world is too    much with us,” “Michael,” and Prelude (1805) book 5:88–98*  Jedediah Purdy, After Nature, “Prologue” and “Introduction”*  February 19: HOLIDAY - no class  February 26:  •  Natalie Diaz (Mojave/Akimel O'odham), “The First Water is the Body”* • Aldo Leopold, “Thinking like a Mountain”*   • Eduardo Kohn, How Forests Think, Introduction (esp pp. 1-10) and Chapter 2*   • Terry Tempest Williams, “The Erotics of Place” *  • Vogel, Thinking Like a Mall, Chapters 1 and 5  Figuring the Human in a More-Than-Human World   March 4: •  Shelley, Frankenstein   •  Ridley Scott’s film “Blade Runner”  March 11: •  Bennett, Vibrant Matter, preface, Chapters 1, 2, 7, 8   •  Robin Wall Kimmerer (Citizen Potawatomi Nation), “The Grammar of Animacy,”  from Braiding Sweetgrass* • Robert MacFarlane, Landmarks, pp. 24-26*
can contact an academic dean in the College by emailing college@brown.edu.  Writing Assistance: If you are struggling with your writing in any portion of the course, please talk to us. For additional help on your writing, consult the expert staff at the Brown Writing Center (https://www.brown.edu/academics/college/support/writing-center/)  Respect For Diversity: Our wish is that students from diverse backgrounds and perspectives be well served by this course, and that the diversity that students bring to this class be viewed as a resource, strength, and benefit. It is our intent to present material in a fashion that is respectful of diversity: gender identity, sexuality, disability, age, socioeconomic status, ethnicity, race, nationality, religion, and culture. Your suggestions are appreciated. Please let us know ways to improve the atmosphere and effectiveness of the course.  Preferred Names and Pronouns: Please advise us at the beginning of the semester what you wish to be called and what pronouns you prefer.   Academic Conduct: Please read Brown University’s policies on academic conduct carefully (http://www.brown.edu/Administration/Dean_of_the_College/curriculum/documents/principles.pdf). Handing in someone else’s work or ideas as your own (even if you worked on it together as a group) constitutes plagiarism, as does using someone’s ideas without appropriate citations, including AI-generated text.
#
#
# Total pages in PDF: 4
# Reading content from page 1 to 3:
# Successfully read page 1
# Successfully read page 2
# Successfully read page 3
#
# Partial document text (pages 1–3):
#  Page 1:
# Brown University HMAN 2400U, Spring 2024  Into the Wild: Thinking Democracy Ecologically  Monday 3:00-5:30     Pembroke 003 Mark Cladis (off hrs Thurs 3:45-5:30)  Sharon Krause (off hrs Wed 12:30-2:30)  How are we to respond to ecological crises that interweave politics, economy, religion, and culture, and that affect and position people differently based on their race, class, gender, sexuality, and other aspects of their identities? What resources do we have—or can we create—for reimagining “the human” and the more-than-human in ways that might be emancipatory for both? What kinds of cultural efforts, artistic work, social practices, and political institutions might figure in this reimagining? This collaborative humanities seminar explores a diverse range of contemporary and historical works ranging from poetry, fiction, and film to theology, social and political theory, nature writing, and environmental studies, including work by Wordsworth, Shelley, Bennett, Vogel, Du Bois, Gomez-Baris, Jarman, and Nixon, among others. The course emphasizes collaborative thinking and writing, both inside and outside the classroom.   Course Requirements (1) Regular attendance.  If you cannot attend a seminar, let us know in advance.  Read the assignments carefully and be prepared to say something about them during our conversations together.  Throughout the semester, we will endeavor to make connections between past and present sessions.    (2) Collaboratively hosting a class session: Groups of 2-3 students will host approximately the first half of one class session (written notes that reflect the dynamic, collaborative preparation for the session will be circulated in advance). Members of the hosting team are not expected to become experts for the sessions lead; they are expected to be informed readers and thoughtful hosts (educators) for our conversations.   (3) Final paper: A final paper of 20-25 pages due on May 13.    (4) Collaboratively edited volume: The final paper will be part of a larger, edited volume of 3 to 5 papers, conceived collaboratively by small groups of students and with a collaboratively written Introduction. Later in the seminar we will discuss the logistics for this edited volume. For now you should know that, based on shared interests, you will form groups of 3 to 5 and you will collaboratively develop a topic/focus for an edited book or journal that will include your final papers and you will co-author an Introduction to the volume.    (5) Retreat: Participation in the course retreat at the end of the term, including a presentation of your  ideas for the final paper and collaboratively edited volume.   Institutional Grade Evaluation Your letter grade will normally be calculated as follows:  Class participation, including hosting sessions: 25%  Collaboratively edited volume (its topic and introduction): 20%  Presentation at the retreat: 10%  Final Paper: 45%
culture,"   in The Greening of Everyday Life: Challenging Practices, Imagining Possibilities, ed. John M. Meyer and Jens M. Kersten, Chapters 1 and 15*   •   https://www.nytimes.com/2016/08/22/science/english-village-becomes-    climate-leader-by-quietly-cleaning-up-its-own-patch.html*   •  Robyn Eckersley, The Green State, Chapter 5*    April 22: • Kyle Whyte “Indigenous Science (fiction) for the Anthropocene: Ancestral Dystopias and Fantasies of Climate Change Crisis” • Leanne Simpson, “The Land as Pedagogy” Chapter 9 in As We Have Always Done* •  Bruno Latour, Facing Gaia, Chapter 8* • Watch together in class: Biidaaban (“The Dawn Comes”)  (a 19 min film by Amanda Strong, a Michif Indigenous filmmaker) [https://www.youtube.com/watch?v=vWjnYKyiUB8]  Retreat (5:15-7:30) Over a catered dinner we will reflect on the course and discuss students’ plans for final papers and the edited volumes. Each group will have 20 minutes to describe the purpose/motivating themes of their volume, including a brief precis of each paper, followed by feedback from the class as a whole.  May 13:   Final papers and edited volumes due by 5 pm. Please send as PDFs and Word docs to both sharon_krause@brown.edu and mark_cladis@brown.edu.

# %%
import docx
from docx.shared import Inches

def read_docx_text(docx_path):
    """
    Read text content from a Word document and return a list of paragraphs

    Args:
        docx_path: Path to the Word document (.docx)
    """
    try:
        # Open the Word document
        doc = docx.Document(docx_path)
        
        # Extract document metadata
        info = {
            "Title": doc.core_properties.title if doc.core_properties.title else "No title",
            "Author": doc.core_properties.author if doc.core_properties.author else "Unknown author",
            "Created": doc.core_properties.created.strftime("%Y-%m-%d %H:%M:%S")
                       if doc.core_properties.created else "No creation time",
            "ParagraphCount": len(doc.paragraphs)
        }
        print(f"Document info:\n{info}\n")
        
        # Extract text from each paragraph
        all_text = ""
        paragraphs = []
        for i, para in enumerate(doc.paragraphs, 1):
            para_text = para.text.strip()
            if para_text:
                paragraphs.append(para_text)
                all_text += f"Paragraph {i}: {para_text}\n"
        
        print(f"Successfully read {len(paragraphs)} non-empty paragraphs\n")
        return all_text, paragraphs, info
    
    except FileNotFoundError:
        print(f"Error: File {docx_path} does not exist")
    except Exception as e:
        print(f"An error occurred while reading the Word document: {e}")
    return "", [], {}

# Example usage
if __name__ == "__main__":
    docx_path = "C:/Users/zlzdego/Downloads/AY 2023-2024/AY 2023-2024/jpVWstdGlchQYBzAquRYEWOUOHfP5nDDjJmFRFUT.docx"  # Replace with your actual Word file path
    
    full_text, para_list, doc_info = read_docx_text(docx_path)
    
    # Print the first 3 paragraphs (example)
    print("First 3 paragraphs of the document:")
    for para in para_list[:3]:
        print("-", para)
# Out:
# Document info:
# {'Title': 'No title', 'Author': 'Mercedes Vaquero', 'Created': '2023-08-07 17:20:00', 'ParagraphCount': 273}
#
# Successfully read 172 non-empty paragraphs
#
# First 3 paragraphs of the document:
# - Hispanic Culture Through Cinema
# - HISP0710B-S01, Fall ‘23
# - Freshman Seminar
