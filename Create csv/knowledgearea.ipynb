# %%
# map each department to a knowledge area
KNOWLEDGE_AREA_MAP = {
    'Africana Studies': 'Social Sciences',
    'American Studies': 'Social Sciences',
    'Annenberg Institute for School Reform': 'Social Sciences',
    'Anthropology': 'Social Sciences',
    'Applied Mathematics': 'Physical Sciences',
    # 'Archaeology and the Ancient World': 'Humanities',
    # 'Behavioral and Social Health Sciences': 'Social Sciences',
    # 'Biology': 'Life Sciences',
    # 'Brown Arts Institute': 'Arts',
    # 'Business, Entrepreneurship, Organizations': 'Social Sciences',
    # 'Carney Institute for Brain Science': 'Life Sciences',
    'Chemistry': 'Physical Sciences',
    'Classics': 'Humanities',
    'Cognitive and Psychological Sciences': 'Life Sciences',
    'Cogut Institute for the Humanities': 'Humanities',
    'Comparative Literature': 'Humanities',
    'Computation and Visualization': 'Physical Sciences',
    # 'Center for Computational Molecular Biology': 'Life Sciences',
    'Computer Science': 'Physical Sciences',
    # 'Data Science Initiative': 'Physical Sciences',
    'Early Cultures': 'Humanities',
    'Earth, Environmental and Planetary Sciences': 'Physical Sciences',
    'East Asian Studies': 'Humanities',
    'Economics': 'Social Sciences',
    'Education': 'Social Sciences',
    'Egyptology and Assyriology': 'Humanities',
    # 'Engineering': 'Physical Sciences',
    'English': 'Humanities',
    'French and Francophone Studies': 'Humanities',
    'German Studies': 'Humanities',
    'Hispanic Studies': 'Humanities',
    'History': 'Social Sciences',
    'History of Art and Architecture': 'Humanities',
    'International and Public Affairs': 'Social Sciences',
    'Italian Studies': 'Humanities',
    'Judaic Studies': 'Humanities',
    'Latin American and Caribbean Studies': 'Social Sciences',
    # 'Linguistics': 'Social Sciences',
    'Literary Arts': 'Humanities',
    'Mathematics': 'Physical Sciences',
    'Medieval Studies': 'Humanities',
    # 'Middle East Studies': 'Humanities',
    'Modern Culture and Media': 'Humanities',
    'Music': 'Humanities',
    # 'Neuroscience': 'Life Sciences',
    'Philosophy': 'Humanities',
    'Physics': 'Physical Sciences',
    'Political Science': 'Social Sciences',
    'Portuguese and Brazilian Studies': 'Humanities',
    # 'Public Health': 'Life Sciences',
    'Program in Science, Technology, and Society': 'Social Sciences',
    'Religious Studies': 'Humanities',
    'Slavic Studies': 'Humanities',
    'Sociology': 'Social Sciences',
    # 'South Asian Studies': 'Humanities',
    'Theatre Arts and Performance Studies': 'Humanities',
    'Urban Studies Program': 'Social Sciences',
    'Visual Art': 'Humanities',
}

# Departments that still need to be mapped please send this over to Linda 
UNMAPPED_DEPARTMENTS = {
    'CLPS': 'Life Sciences',
    'PHP': 'Life Sciences',
    'ENVS': 'Social Sciences',
    'ARCH': 'Humanities',
    'ENGN': 'Physical Sciences',
    'Ecology': 'Life Sciences',
    'COST': 'Humanities',
    'German': 'Humanities',
    'ARAB': 'Humanities',
    'HMAN': 'Humanities',
    'MPA': 'Social Sciences',
    'WLC': 'Humanities',
    'PRSN': 'Humanities',
    'ETHN': 'Social Sciences',
    'INDP': 'N/A',
    'NAIS': 'Humanities',
    'UNIV': 'N/A',
    'GPHP': 'Life Sciences',
    'PLME': 'Life Sciences',
    'ARTS': 'Humanities',
    'Middle East Studies': 'Humanities',
    'LANG': 'Humanities',
    'DATA': 'Physical Sciences',
    'NEUR': 'Life Sciences',
    'GNSS': 'Humanities',
    'BIOM': 'Life Sciences'
}

# %% [markdown]
# Questions: How should we label courses and departments where the course code is a subfield of the department? As in CHIN being a subbranch of East Asian Studies, as opposed to SOC being solely under sociology? Leave Chinese as Chinese, rather than department. As sub-fields as possible.
#
# How do you categorize programs, academic departments, etc? For example, the Watson institute. Treat them like departments. Go all the way down to the four letter code.
#
# Just put labels on the ones that don't have course titles on them. (Unknown syllabus 1, syllabus 2, etc.)
